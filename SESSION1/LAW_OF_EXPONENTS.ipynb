# %% [markdown]
# <a href="https://colab.research.google.com/github/AndresNamm/MATH1/blob/main/SESSION1/LAW_OF_EXPONENTS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# [Law of exponents](https://adaptavist.udemy.com/course/math-with-python/learn/lecture/16210304#overview)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
print(3**2 * 3 **4)
print(3**(2+4))
# Out:
# 729
# 729

# %%
from IPython.display import Math, HTML, display

def load_mathjax_in_cell_output():
  display(HTML("<script src='https://www.gstatic.com/external_hosted/"
               "mathjax/latest/MathJax.js?config=default'></script>"))
get_ipython().events.register('pre_run_cell', load_mathjax_in_cell_output)

# %%
display(Math('3^2\\times 3^4 = 3^{2+4}'))
# Out:
# <script src='https://www.gstatic.com/external_hosted/mathjax/latest/MathJax.js?config=default'></script>
# $$3^2\times 3^4 = 3^{2+4}$$

# %%
display(Math('x^y\\times x^z = x^{y+z}'))
# Out:
# <script src='https://www.gstatic.com/external_hosted/mathjax/latest/MathJax.js?config=default'></script>
# $$x^y\times x^z = x^{y+z}$$
